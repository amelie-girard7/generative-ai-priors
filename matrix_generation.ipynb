# %%
import numpy as np
import pandas as pd

# List of unique variables
variables = [
    "BMI", "BMI1", "BMI2", "FTA", "CD", "DP1", "EG", "EM", "FH", "FS", "INC", "P1E", "P2E", "OD", "RP1", "SE",
    "SL", "SEX", "TV", "BWZ", "GW", "FV", "HF", "HSD", "SLD", "LOTE"
]

# Relationships provided as input
relationships = """
BMI, BMI1	Yes
BMI1, BMI	Yes
BMI, BMI2	Yes
BMI2, BMI	Yes
BMI, FTA	Yes
FTA, BMI	Yes
BMI, CD	No
CD, BMI	No
BMI, DP1	No
DP1, BMI	No
BMI, EG	Yes
EG, BMI	Yes
BMI, EM	No
EM, BMI	No
BMI, FH	No
FH, BMI	No
BMI, FS	No
FS, BMI	No
BMI, INC	No
INC, BMI	No
BMI, P1E	No
P1E, BMI	No
BMI, P2E	No
P2E, BMI	No
BMI, OD	No
OD, BMI	No
BMI, RP1	No
RP1, BMI	No
BMI, SE	No
SE, BMI	No
BMI, SL	No
SL, BMI	No
BMI, SEX	No
SEX, BMI	No
BMI, TV	Yes
TV, BMI	Yes
BMI, BWZ	No
BWZ, BMI	No
BMI, GW	No
GW, BMI	No
BMI, FV	No
FV, BMI	No
BMI, HF	Yes
HF, BMI	Yes
BMI, HSD	Yes
HSD, BMI	Yes
BMI, SLD	No
SLD, BMI	No
BMI, LOTE	No
LOTE, BMI	No
BMI1, BMI2	Yes
BMI2, BMI1	Yes
BMI1, FTA	Yes
FTA, BMI1	Yes
BMI1, CD	No
CD, BMI1	No
BMI1, DP1	Yes
DP1, BMI1	Yes
BMI1, EG	Yes
EG, BMI1	Yes
BMI1, EM	Yes
EM, BMI1	Yes
BMI1, FH	Yes
FH, BMI1	Yes
BMI1, FS	Yes
FS, BMI1	Yes
BMI1, INC	No
INC, BMI1	Yes
BMI1, P1E	No
P1E, BMI1	No
BMI1, P2E	No
P2E, BMI1	No
BMI1, OD	Yes
OD, BMI1	Yes
BMI1, RP1	No
RP1, BMI1	No
BMI1, SE	Yes
SE, BMI1	Yes
BMI1, SL	Yes
SL, BMI1	Yes
BMI1, SEX	No
SEX, BMI1	No
BMI1, TV	Yes
TV, BMI1	Yes
BMI1, BWZ	Yes
BWZ, BMI1	Yes
BMI1, GW	No
GW, BMI1	No
BMI1, FV	Yes
FV, BMI1	Yes
BMI1, HF	Yes
HF, BMI1	Yes
BMI1, HSD	Yes
HSD, BMI1	Yes
BMI1, SLD	No
SLD, BMI1	Yes
BMI1, LOTE	No
LOTE, BMI1	No
BMI2, FTA	Yes
FTA, BMI2	Yes
BMI2, CD	No
CD, BMI2	No
BMI2, DP1	Yes
DP1, BMI2	Yes
BMI2, EG	Yes
EG, BMI2	Yes
BMI2, EM	Yes
EM, BMI2	Yes
BMI2, FH	Yes
FH, BMI2	Yes
BMI2, FS	Yes
FS, BMI2	Yes
BMI2, INC	No
INC, BMI2	No
BMI2, P1E	No
P1E, BMI2	No
BMI2, P2E	No
P2E, BMI2	No
BMI2, OD	Yes
OD, BMI2	Yes
BMI2, RP1	No
RP1, BMI2	No
BMI2, SE	No
SE, BMI2	No
BMI2, SL	No
SL, BMI2	No
BMI2, SEX	No
SEX, BMI2	No
BMI2, TV	Yes
TV, BMI2	Yes
BMI2, BWZ	Yes
BWZ, BMI2	Yes
BMI2, GW	No
GW, BMI2	No
BMI2, FV	Yes
FV, BMI2	Yes
BMI2, HF	Yes
HF, BMI2	Yes
BMI2, HSD	Yes
HSD, BMI2	Yes
BMI2, SLD	No
SLD, BMI2	No
BMI2, LOTE	No
LOTE, BMI2	No
FTA, CD	No
CD, FTA	No
FTA, DP1	Yes
DP1, FTA	Yes
FTA, EG	Yes
EG, FTA	Yes
FTA, EM	Yes
EM, FTA	Yes
FTA, FH	No
FH, FTA	Yes
FTA, FS	No
FS, FTA	Yes
FTA, INC	No
INC, FTA	No
FTA, P1E	No
P1E, FTA	No
FTA, P2E	No
P2E, FTA	No
FTA, OD	Yes
OD, FTA	Yes
FTA, RP1	No
RP1, FTA	No
FTA, SE	No
SE, FTA	No
FTA, SL	No
SL, FTA	No
FTA, SEX	No
SEX, FTA	No
FTA, TV	Yes
TV, FTA	Yes
FTA, BWZ	No
BWZ, FTA	No
FTA, GW	No
GW, FTA	No
FTA, FV	No
FV, FTA	No
FTA, HF	No
HF, FTA	No
FTA, HSD	No
HSD, FTA	No
FTA, SLD	No
SLD, FTA	No
FTA, LOTE	No
LOTE, FTA	No
CD, DP1	Yes
DP1, CD	Yes
CD, EG	Yes
EG, CD	Yes
CD, EM	Yes
EM, CD	Yes
CD, FH	Yes
FH, CD	Yes
CD, FS	Yes
FS, CD	Yes
CD, INC	No
INC, CD	No
CD, P1E	No
P1E, CD	No
CD, P2E	No
P2E, CD	No
CD, OD	Yes
OD, CD	Yes
CD, RP1	Yes
RP1, CD	No
CD, SE	No
SE, CD	No
CD, SL	No
SL, CD	No
CD, SEX	No
SEX, CD	No
CD, TV	Yes
TV, CD	Yes
CD, BWZ	No
BWZ, CD	No
CD, GW	No
GW, CD	No
CD, FV	No
FV, CD	No
CD, HF	Yes
HF, CD	Yes
CD, HSD	Yes
HSD, CD	Yes
CD, SLD	No
SLD, CD	No
CD, LOTE	No
LOTE, CD	No
DP1, EG	Yes
EG, DP1	Yes
DP1, EM	Yes
EM, DP1	Yes
DP1, FH	Yes
FH, DP1	Yes
DP1, FS	Yes
FS, DP1	Yes
DP1, INC	No
INC, DP1	No
DP1, P1E	No
P1E, DP1	No
DP1, P2E	No
P2E, DP1	No
DP1, OD	Yes
OD, DP1	Yes
DP1, RP1	Yes
RP1, DP1	No
DP1, SE	No
SE, DP1	No
DP1, SL	No
SL, DP1	No
DP1, SEX	No
SEX, DP1	No
DP1, TV	Yes
TV, DP1	Yes
DP1, BWZ	No
BWZ, DP1	No
DP1, GW	No
GW, DP1	No
DP1, FV	No
FV, DP1	No
DP1, HF	No
HF, DP1	No
DP1, HSD	No
HSD, DP1	No
DP1, SLD	No
SLD, DP1	No
DP1, LOTE	No
LOTE, DP1	No
EG, EM	Yes
EM, EG	Yes
EG, FH	Yes
FH, EG	Yes
EG, FS	No
FS, EG	No
EG, INC	No
INC, EG	No
EG, P1E	No
P1E, EG	No
EG, P2E	No
P2E, EG	Yes
EG, OD	Yes
OD, EG	No
EG, RP1	No
RP1, EG	No
EG, SE	No
SE, EG	No
EG, SL	Yes
SL, EG	Yes
EG, SEX	Yes
SEX, EG	Yes
EG, TV	No
TV, EG	No
EG, BWZ	No
BWZ, EG	No
EG, GW	No
GW, EG	No
EG, FV	No
FV, EG	No
EG, HF	No
HF, EG	No
EG, HSD	No
HSD, EG	No
EG, SLD	No
SLD, EG	No
EG, LOTE	No
LOTE, EG	No
EM, FH	Yes
FH, EM	Yes
EM, FS	No
FS, EM	No
EM, INC	No
INC, EM	No
EM, P1E	No
P1E, EM	No
EM, P2E	No
P2E, EM	No
EM, OD	No
OD, EM	No
EM, RP1	No
RP1, EM	No
EM, SE	No
SE, EM	No
EM, SL	No
SL, EM	No
EM, SEX	No
SEX, EM	No
EM, TV	No
TV, EM	No
EM, BWZ	No
BWZ, EM	No
EM, GW	No
GW, EM	No
EM, FV	Yes
FV, EM	Yes
EM, HF	Yes
HF, EM	Yes
EM, HSD	No
HSD, EM	No
EM, SLD	No
SLD, EM	No
EM, LOTE	No
LOTE, EM	Yes
FH, FS	No
FS, FH	No
FH, INC	No
INC, FH	No
FH, P1E	No
P1E, FH	No
FH, P2E	No
P2E, FH	No
FH, OD	No
OD, FH	No
FH, RP1	No
RP1, FH	No
FH, SE	No
SE, FH	No
FH, SL	No
SL, FH	No
FH, SEX	No
SEX, FH	No
FH, TV	No
TV, FH	No
FH, BWZ	No
BWZ, FH	No
FH, GW	Yes
GW, FH	Yes
FH, FV	Yes
FV, FH	Yes
FH, HF	No
HF, FH	No
FH, HSD	Yes
HSD, FH	Yes
FH, SLD	Yes
SLD, FH	Yes
FH, LOTE	Yes
LOTE, FH	Yes
FS, INC	Yes
INC, FS	No
FS, P1E	No
P1E, FS	Yes
FS, P2E	Yes
P2E, FS	Yes
FS, OD	No
OD, FS	No
FS, RP1	No
RP1, FS	No
FS, SE	No
SE, FS	No
FS, SL	No
SL, FS	No
FS, SEX	No
SEX, FS	No
FS, TV	No
TV, FS	No
FS, BWZ	Yes
BWZ, FS	Yes
FS, GW	Yes
GW, FS	Yes
FS, FV	No
FV, FS	No
FS, HF	Yes
HF, FS	Yes
FS, HSD	Yes
HSD, FS	Yes
FS, SLD	No
SLD, FS	No
FS, LOTE	No
LOTE, FS	No
INC, P1E	Yes
P1E, INC	Yes
INC, P2E	No
P2E, INC	No
INC, OD	No
OD, INC	No
INC, RP1	No
RP1, INC	No
INC, SE	No
SE, INC	No
INC, SL	No
SL, INC	No
INC, SEX	Yes
SEX, INC	Yes
INC, TV	No
TV, INC	No
INC, BWZ	No
BWZ, INC	No
INC, GW	No
GW, INC	No
INC, FV	No
FV, INC	No
INC, HF	No
HF, INC	No
INC, HSD	No
HSD, INC	No
INC, SLD	Yes
SLD, INC	Yes
INC, LOTE	No
LOTE, INC	No
P1E, P2E	No
P2E, P1E	No
P1E, OD	No
OD, P1E	No
P1E, RP1	No
RP1, P1E	No
P1E, SE	No
SE, P1E	No
P1E, SL	Yes
SL, P1E	Yes
P1E, SEX	No
SEX, P1E	No
P1E, TV	No
TV, P1E	No
P1E, BWZ	No
BWZ, P1E	No
P1E, GW	No
GW, P1E	No
P1E, FV	No
FV, P1E	No
P1E, HF	No
HF, P1E	No
P1E, HSD	No
HSD, P1E	No
P1E, SLD	No
SLD, P1E	No
P1E, LOTE	No
LOTE, P1E	No
P2E, OD	No
OD, P2E	No
P2E, RP1	No
RP1, P2E	No
P2E, SE	No
SE, P2E	No
P2E, SL	No
SL, P2E	No
P2E, SEX	No
SEX, P2E	No
P2E, TV	No
TV, P2E	No
P2E, BWZ	No
BWZ, P2E	No
P2E, GW	No
GW, P2E	No
P2E, FV	No
FV, P2E	No
P2E, HF	No
HF, P2E	No
P2E, HSD	Yes
HSD, P2E	Yes
P2E, SLD	No
SLD, P2E	No
P2E, LOTE	No
LOTE, P2E	No
OD, RP1	Yes
RP1, OD	Yes
OD, SE	Yes
SE, OD	Yes
OD, SL	Yes
SL, OD	Yes
OD, SEX	No
SEX, OD	No
OD, TV	No
TV, OD	No
OD, BWZ	No
BWZ, OD	No
OD, GW	No
GW, OD	No
OD, FV	No
FV, OD	No
OD, HF	Yes
HF, OD	Yes
OD, HSD	Yes
HSD, OD	Yes
OD, SLD	Yes
SLD, OD	Yes
OD, LOTE	No
LOTE, OD	No
RP1, SE	No
SE, RP1	No
RP1, SL	No
SL, RP1	No
RP1, SEX	No
SEX, RP1	No
RP1, TV	No
TV, RP1	No
RP1, BWZ	No
BWZ, RP1	No
RP1, GW	No
GW, RP1	No
RP1, FV	No
FV, RP1	No
RP1, HF	No
HF, RP1	No
RP1, HSD	No
HSD, RP1	No
RP1, SLD	No
SLD, RP1	No
RP1, LOTE	Yes
LOTE, RP1	Yes
SE, SL	No
SL, SE	No
SE, SEX	No
SEX, SE	No
SE, TV	No
TV, SE	No
SE, BWZ	No
BWZ, SE	No
SE, GW	No
GW, SE	No
SE, FV	No
FV, SE	No
SE, HF	No
HF, SE	No
SE, HSD	No
HSD, SE	No
SE, SLD	No
SLD, SE	No
SE, LOTE	No
LOTE, SE	No
SL, SEX	No
SEX, SL	No
SL, TV	No
TV, SL	No
SL, BWZ	No
BWZ, SL	No
SL, GW	No
GW, SL	No
SL, FV	No
FV, SL	No
SL, HF	No
HF, SL	No
SL, HSD	No
HSD, SL	No
SL, SLD	No
SLD, SL	No
SL, LOTE	No
LOTE, SL	No
SEX, TV	No
TV, SEX	No
SEX, BWZ	No
BWZ, SEX	No
SEX, GW	No
GW, SEX	No
SEX, FV	No
FV, SEX	No
SEX, HF	No
HF, SEX	No
SEX, HSD	No
HSD, SEX	No
SEX, SLD	No
SLD, SEX	No
SEX, LOTE	No
LOTE, SEX	No
TV, BWZ	No
BWZ, TV	No
TV, GW	No
GW, TV	No
TV, FV	No
FV, TV	No
TV, HF	No
HF, TV	No
TV, HSD	No
HSD, TV	No
TV, SLD	No
SLD, TV	No
TV, LOTE	No
LOTE, TV	No
BWZ, GW	No
GW, BWZ	No
BWZ, FV	No
FV, BWZ	No
BWZ, HF	No
HF, BWZ	No
BWZ, HSD	No
HSD, BWZ	No
BWZ, SLD	No
SLD, BWZ	No
BWZ, LOTE	Yes
LOTE, BWZ	Yes
GW, FV	Yes
FV, GW	Yes
GW, HF	Yes
HF, GW	Yes
GW, HSD	Yes
HSD, GW	Yes
GW, SLD	Yes
SLD, GW	Yes
GW, LOTE	Yes
LOTE, GW	No
FV, HF	No
HF, FV	No
FV, HSD	No
HSD, FV	No
FV, SLD	No
SLD, FV	No
FV, LOTE	No
LOTE, FV	No
HF, HSD	No
HSD, HF	Yes
HF, SLD	Yes
SLD, HF	No
HF, LOTE	No
LOTE, HF	Yes
HSD, SLD	Yes
SLD, HSD	No
HSD, LOTE	No
LOTE, HSD	Yes
SLD, LOTE	Yes
LOTE, SLD	Yes
"""

# Split the relationships into lines
lines = relationships.strip().split("\n")

# Create a mapping of variables to indices
var_to_idx = {var: idx for idx, var in enumerate(variables)}

# Initialize the matrix
n = len(variables)
matrix = np.zeros((n, n), dtype=int)

# Populate the matrix
for line in lines:
    var1, var2, value = line.split("\t")[0].split(", ") + [line.split("\t")[1]]
    i, j = var_to_idx[var1], var_to_idx[var2]
    matrix[i, j] = 1 if value == "Yes" else 0

# Convert the matrix to a DataFrame
df = pd.DataFrame(matrix, index=variables, columns=variables)

# Save the DataFrame to a CSV file
csv_file_path = "matrix.csv"
df.to_csv(csv_file_path)

print(f"Matrix saved to {csv_file_path}")
# Out:
# Matrix saved to matrix.csv
